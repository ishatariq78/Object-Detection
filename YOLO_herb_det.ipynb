# %%
import os
import numpy as np
import glob as glob
import matplotlib.pyplot as plt
import random
import cv2
import requests
from IPython.display import Image
from tqdm import tqdm
# !pip install IProgress
from ipywidgets import IntProgress

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JaHbuZAnQIPRBy5b2aU8")
project = rf.workspace("national-university-of-science-and-technology").project("plant_6")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}' for x in p5]

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# ...
# 100%|██████████| 3.87M/3.87M [00:00<00:00, 78.8MB/s]
#
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 165MB/s]
#
# ...
# 100%|██████████| 40.8M/40.8M [00:00<00:00, 69.8MB/s]
#
# ...
# 100%|██████████| 89.3M/89.3M [00:00<00:00, 162MB/s]
#
# ...
# 100%|██████████| 166M/166M [00:00<00:00, 230MB/s]

# %%
# !python /content/yolov5/train.py --data /content/yolov5/plant_6-1/data.yaml --weights /content/yolov5/weights/yolov5s.pt --img 416 --batch 16 --epochs 20
# Out:
# 2023-12-29 14:34:50.063075: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-29 14:34:50.063230: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-29 14:34:50.074531: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.20 --source /content/yolov5/plant_6-1/test/images
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/plant_6-1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/53 /content/yolov5/plant_6-1/test/images/102_JPG_jpg.rf.d980ab018da065cbabd89e71d0cdae84.jpg: 416x416 1 lettuce, 281.0ms
# image 2/53 /content/yolov5/plant_6-1/test/images/109_JPG_jpg.rf.d02f021fbf7cb1f5f15e15f8b6fd4ed5.jpg: 416x416 1 lettuce, 251.1ms
# ...
